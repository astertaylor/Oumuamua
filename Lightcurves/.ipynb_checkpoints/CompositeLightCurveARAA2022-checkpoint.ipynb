# %%
import numpy as np
# %matplotlib inline


import matplotlib.pyplot as plt



COLOR = 'k'#'#FFFAF1'
plt.rcParams['font.size'] = 20
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

plt.rcParams['xtick.major.width'] = 3
plt.rcParams['ytick.major.width'] = 3
plt.rcParams['xtick.major.size']  = 14 #12
plt.rcParams['ytick.major.size']  = 14#12

plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size']  = 8
plt.rcParams['ytick.minor.size']  = 8

plt.rcParams['axes.linewidth'] = 3

plt.rcParams['text.color'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
#plt.rcParams['axes.spines.top'] = False
#plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['axes.edgecolor'] = COLOR
plt.rcParams['figure.facecolor'] = 'none'
plt.rcParams['legend.facecolor'] = 'none'
from matplotlib.gridspec import GridSpec

# %%
plotA=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotA.csv',comments='#', delimiter=',' )
plotB=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotB.csv',comments='#', delimiter=',' )
plotC=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotC.csv',comments='#', delimiter=',' )
plotD=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotD.csv',comments='#', delimiter=',' )
plotE=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotE.csv',comments='#', delimiter=',' )
plotF=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotF.csv',comments='#', delimiter=',' )
plotG=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotG.csv',comments='#', delimiter=',' )
plotH=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotH.csv',comments='#', delimiter=',' )
plotI=np.genfromtxt('/Users/darrylseligman/Oumuamua/New_Acceleration_Analysis/LightCurve_Analysis/redigitizeafigure/plotI.csv',comments='#', delimiter=',' )

# %%
fig, ax1 = plt.subplots(1, 1, tight_layout=True,figsize=(12,4))
ax1.set_ylim([25.9,21.])

ax1.scatter(plotA[:,0],plotA[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax1.scatter(plotB[:,0],plotB[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax1.scatter(plotC[:,0],plotC[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax1.scatter(plotD[:,0],plotD[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')

ax1.scatter(plotE[:,0],plotE[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax1.scatter(plotF[:,0],plotF[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
# Out:
# /Users/darrylseligman/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(20,10),sharey=True)
ax = axes.reshape(-1)
#fig.set_facecolor('w')

d = .025
c=100

mcolor = COLOR

for j in range(0,10):
    ## Middle subpanels
    if j!=0 and j!=5 and j!=4 and j!=9:
        ax[j].spines['right'].set_visible(False)
        ax[j].spines['left'].set_visible(False)
        ax[j].set_yticks([])
        
        kwargs = dict(transform=ax[j].transAxes, color=COLOR, clip_on=False)
        ax[j].plot((1-d,1+d), (-d,+d), **kwargs)
        ax[j].plot((1-d,1+d),(1-d,1+d), **kwargs)
        kwargs.update(transform=ax[j].transAxes)  # switch to the bottom axes
        ax[j].plot((-d,+d), (1-d,1+d), **kwargs)
        ax[j].plot((-d,+d), (-d,+d), **kwargs)
        
    ## First subpanel per row
    elif j == 0 or j == 5:
        ax[j].spines['right'].set_visible(False)
        
        kwargs = dict(transform=ax[j].transAxes, color=COLOR, clip_on=False)
        ax[j].plot((1-d,1+d), (-d,+d), **kwargs)
        ax[j].plot((1-d,1+d),(1-d,1+d), **kwargs)
        
    ## Last subpanel per row
    elif j == 4 or j == 9:
        ax[j].spines['left'].set_visible(False)
        ax[j].set_yticks([])
        
        kwargs.update(transform=ax[j].transAxes)  # switch to the bottom axes
        ax[j].plot((-d,+d), (1-d,1+d), **kwargs)
        ax[j].plot((-d,+d), (-d,+d), **kwargs)

plt.subplots_adjust(wspace=0.05, hspace=0.3)

ax[0].set_ylim([25.9,21.])


ax[0].scatter(plotA[:,0],plotA[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[0].set_xlim([plotA[0,0]-0.1,plotA[0,0]-0.1+plotC[-1,0]-plotC[0,0]])
ax[1].scatter(plotB[:,0],plotB[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[1].set_xlim([plotB[0,0]-0.1,plotB[0,0]-0.1+plotC[-1,0]-plotC[0,0]])
ax[2].scatter(plotC[:,0],plotC[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[2].set_xlim([plotC[0,0],plotC[-1,0]])
ax[3].scatter(plotD[:,0],plotD[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[3].set_xlim([plotD[0,0]-0.01,plotD[0,0]-0.01+plotC[-1,0]-plotC[0,0]])


ax[4].scatter(plotE[:,0],plotE[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[4].set_xlim([plotE[0,0]-0.1,plotE[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

ax[5].scatter(plotF[:,0],plotF[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')

ax[5].set_xlim([plotF[0,0]-0.01,plotF[0,0]-0.01+plotC[-1,0]-plotC[0,0]])
# Out:
# (55.814, 56.27199999999999)

# %%
fig, axes = plt.subplots(ncols=6, nrows=2, figsize=(20,10),sharey=True)

# %%
fig, axes = plt.subplots(ncols=6, nrows=2, figsize=(20,10),sharey=True)
ax = axes.reshape(-1)
#fig.set_facecolor('w')

d = .025
c=100

mcolor = COLOR

ender=9
for j in range(0,ender):
    ## Middle subpanels
    if j!=0 and j!=6 and j!=5 and j!=ender-1 and j<ender:
        ax[j].spines['right'].set_visible(False)
        ax[j].spines['left'].set_visible(False)
        ax[j].set_yticks([])
        
        kwargs = dict(transform=ax[j].transAxes, color=COLOR, clip_on=False)
        ax[j].plot((1-d,1+d), (-d,+d), **kwargs)
        ax[j].plot((1-d,1+d),(1-d,1+d), **kwargs)
        kwargs.update(transform=ax[j].transAxes)  # switch to the bottom axes
        ax[j].plot((-d,+d), (1-d,1+d), **kwargs)
        ax[j].plot((-d,+d), (-d,+d), **kwargs)
        
    ## First subpanel per row
    elif j == 0 or j == 6:
        ax[j].spines['right'].set_visible(False)
        
        kwargs = dict(transform=ax[j].transAxes, color=COLOR, clip_on=False)
        ax[j].plot((1-d,1+d), (-d,+d), **kwargs)
        ax[j].plot((1-d,1+d),(1-d,1+d), **kwargs)
        
    ## Last subpanel per row
    elif j == 5 or j == ender-1:
        ax[j].spines['left'].set_visible(False)
        ax[j].set_yticks([])
        
        kwargs.update(transform=ax[j].transAxes)  # switch to the bottom axes
        ax[j].plot((-d,+d), (1-d,1+d), **kwargs)
        ax[j].plot((-d,+d), (-d,+d), **kwargs)

plt.subplots_adjust(wspace=0.05, hspace=0.3)

ax[0].set_ylim([25.9,21.])


ax[0].scatter(plotA[:,0],plotA[:,1],s=50,edgecolors='k', linewidths=0.4,marker='o',color='orange',label='VLT')
ax[0].set_xlim([plotA[0,0]-0.1,plotA[0,0]-0.1+plotC[-1,0]-plotC[0,0]])


#split up Oct 26 nights
ax[1].scatter(plotB[:,0][np.where(plotB[:,0]>52.11)],plotB[:,1][np.where(plotB[:,0]>52.11)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='orange',label='VLT')


ax[1].scatter(plotB[:,0][np.where(plotB[:,0]<52.05)],plotB[:,1][np.where(plotB[:,0]<52.05)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='purple',label='NOT')

ax[1].scatter(plotB[:,0][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))],plotB[:,1][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='red',label='GS')

ax[1].set_xlim([plotB[0,0]-0.1,plotB[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

#Octorber 27
ax[2].scatter(plotC[:,0][np.where(plotC[:,0]<53.26)],plotC[:,1][np.where(plotC[:,0]<53.26)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='red',label='GS')

ax[2].scatter(plotC[:,0][np.where(plotC[:,0]>53.4)],plotC[:,1][np.where(plotC[:,0]>53.4)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue',label='GN')

ax[2].scatter(plotC[:,0][np.where((plotC[:,0]>53.26)&(plotC[:,0]<53.4))],
              plotC[:,1][np.where((plotC[:,0]>53.26)&(plotC[:,0]<53.4))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='yellow',label='CFH')


ax[2].set_xlim([plotC[0,0],plotC[-1,0]])


#October 28
ax[3].scatter(plotD[:,0][np.where(plotD[:,0]<54.23)],plotD[:,1][np.where(plotD[:,0]<54.23)],
              s=60,edgecolors='k', linewidths=0.4,marker='o',color='silver',label='WIYN')

ax[3].scatter(plotD[:,0][np.where(plotD[:,0]>54.23)],plotD[:,1][np.where(plotD[:,0]>54.23)],
              s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue',label='GN')


ax[3].set_xlim([plotD[0,0]-0.01,plotD[0,0]-0.01+plotC[-1,0]-plotC[0,0]])

#October 29
ax[4].scatter(plotE[:,0],plotE[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[4].set_xlim([plotE[0,0]-0.1,plotE[0,0]-0.1+plotC[-1,0]-plotC[0,0]])


#October 30
ax[5].scatter(plotF[:,0][np.where(plotF[:,0]<55.9)],plotF[:,1][np.where(plotF[:,0]<55.9)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='green',label='WHT')
ax[5].scatter(plotF[:,0][np.where(plotF[:,0]>56.1)],plotF[:,1][np.where(plotF[:,0]>56.1)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='pink',label='DCT')


ax[5].scatter(plotF[:,0][np.where((plotF[:,0]<56.1)&(plotF[:,0]>55.9))],
              plotF[:,1][np.where((plotF[:,0]<56.1)&(plotF[:,0]>55.9))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='purple',label='NOT')


ax[5].set_xlim([plotF[0,0]-0.01,plotF[0,0]-0.01+plotC[-1,0]-plotC[0,0]])


ax[0].set_title('Oct 25',fontsize=15)
ax[1].set_title('Oct 26',fontsize=15)
ax[2].set_title('Oct 27',fontsize=15)
ax[3].set_title('Oct 28',fontsize=15)
ax[4].set_title('Oct 29',fontsize=15)

ax[5].set_title('Oct 30',fontsize=15)
ax[10].axis('off')
ax[11].axis('off')
ax[9].axis('off')

ax[6].scatter(plotG[:,0],plotG[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='violet',label='HST')
ax[6].set_xlim([plotG[0,0]-0.1,plotG[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

ax[7].scatter(plotH[:,0],plotH[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='violet',label='HST')
ax[7].set_xlim([plotH[0,0]-0.1,plotH[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

ax[8].scatter(plotI[:,0],plotI[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='yellow',label='CFH')
ax[8].set_xlim([plotI[0,0]-0.1,plotI[0,0]-0.1+plotC[-1,0]-plotC[0,0]])
#ax7.plot(plotG[:,0],plotG[:,1],'ko')
#ax8.plot(plotH[:,0],plotH[:,1],'ko')
#ax9.plot(plotI[:,0],plotI[:,1],'ko')

ax[6].set_title('Nov 21',fontsize=15)
ax[7].set_title('Nov 22',fontsize=15)
ax[8].set_title('Nov 23',fontsize=15)
ax[8].scatter(plotH[:,0],plotH[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='violet',label='HST')
ax[8].scatter(plotB[:,0][np.where(plotB[:,0]>52.11)],plotB[:,1][np.where(plotB[:,0]>52.11)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='orange',label='VLT')


ax[8].scatter(plotB[:,0][np.where(plotB[:,0]<52.05)],plotB[:,1][np.where(plotB[:,0]<52.05)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='purple',label='NOT')

ax[8].scatter(plotB[:,0][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))],plotB[:,1][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='red',label='GS')
ax[8].scatter(plotC[:,0][np.where(plotC[:,0]>53.4)],plotC[:,1][np.where(plotC[:,0]>53.4)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue',label='GN')

ax[8].scatter(plotD[:,0][np.where(plotD[:,0]<54.23)],plotD[:,1][np.where(plotD[:,0]<54.23)],
              s=60,edgecolors='k', linewidths=0.4,marker='o',color='silver',label='WIYN')
ax[8].scatter(plotF[:,0][np.where(plotF[:,0]<55.9)],plotF[:,1][np.where(plotF[:,0]<55.9)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='green',label='WHT')
ax[8].scatter(plotF[:,0][np.where(plotF[:,0]>56.1)],plotF[:,1][np.where(plotF[:,0]>56.1)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='pink',label='DCT')

ax[8].legend(fancybox=True, framealpha=1, shadow=False, borderpad=1,bbox_to_anchor=(1.8,0),
            frameon=True, loc='lower right', ncol=1,prop={'size': 16},facecolor='none')


plt.savefig('Oumuamua_LightCurve_ARAA.pdf',
            rasterize=True, bbox_inches='tight', dpi=300, transparent=True)

# %%
fig, axes = plt.subplots(ncols=6, nrows=2, figsize=(20,10))#,sharey=True)
ax = axes.reshape(-1)
#fig.set_facecolor('w')

d = .025
c=100

mcolor = COLOR

for j in range(0,ender):
    ax[j].set_ylim([25.3,21.2])
    #ax[j].grid(True,alpha=.6)


ender=9
for j in range(0,ender):
    ## Middle subpanels
    if j!=0 and j!=6 and j!=5 and j!=ender-1 and j<ender:
        ax[j].spines['right'].set_visible(False)
        ax[j].spines['left'].set_visible(False)
        ax[j].set_yticks([])
        
        kwargs = dict(transform=ax[j].transAxes, color=COLOR, clip_on=False)
        ax[j].plot((1-d,1+d), (-d,+d), **kwargs)
        ax[j].plot((1-d,1+d),(1-d,1+d), **kwargs)
        kwargs.update(transform=ax[j].transAxes)  # switch to the bottom axes
        ax[j].plot((-d,+d), (1-d,1+d), **kwargs)
        ax[j].plot((-d,+d), (-d,+d), **kwargs)
        
    ## First subpanel per row
    elif j == 0 or j == 6:
        ax[j].spines['right'].set_visible(False)
        
        kwargs = dict(transform=ax[j].transAxes, color=COLOR, clip_on=False)
        ax[j].plot((1-d,1+d), (-d,+d), **kwargs)
        ax[j].plot((1-d,1+d),(1-d,1+d), **kwargs)
        
    ## Last subpanel per row
    elif j == 5 or j == ender-1:
        ax[j].spines['left'].set_visible(False)
        ax[j].set_yticks([])
        
        kwargs.update(transform=ax[j].transAxes)  # switch to the bottom axes
        ax[j].plot((-d,+d), (1-d,1+d), **kwargs)
        ax[j].plot((-d,+d), (-d,+d), **kwargs)

plt.subplots_adjust(wspace=0.05, hspace=0.3)



ax[0].scatter(plotA[:,0],plotA[:,1],s=50,edgecolors='k', linewidths=0.4,marker='o',color='orange',label='VLT')
ax[0].set_xlim([plotA[0,0]-0.1,plotA[0,0]-0.1+plotC[-1,0]-plotC[0,0]])


#split up Oct 26 nights
ax[1].scatter(plotB[:,0][np.where(plotB[:,0]>52.11)],plotB[:,1][np.where(plotB[:,0]>52.11)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='orange',label='VLT')


ax[1].scatter(plotB[:,0][np.where(plotB[:,0]<52.05)],plotB[:,1][np.where(plotB[:,0]<52.05)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='purple',label='NOT')

ax[1].scatter(plotB[:,0][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))],plotB[:,1][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='red',label='GS')

ax[1].set_xlim([plotB[0,0]-0.1,plotB[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

#Octorber 27
ax[2].scatter(plotC[:,0][np.where(plotC[:,0]<53.26)],plotC[:,1][np.where(plotC[:,0]<53.26)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='red',label='GS')

ax[2].scatter(plotC[:,0][np.where(plotC[:,0]>53.4)],plotC[:,1][np.where(plotC[:,0]>53.4)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue',label='GN')

ax[2].scatter(plotC[:,0][np.where((plotC[:,0]>53.26)&(plotC[:,0]<53.4))],
              plotC[:,1][np.where((plotC[:,0]>53.26)&(plotC[:,0]<53.4))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='yellow',label='CFH')


ax[2].set_xlim([plotC[0,0],plotC[-1,0]])


#October 28
ax[3].scatter(plotD[:,0][np.where(plotD[:,0]<54.23)],plotD[:,1][np.where(plotD[:,0]<54.23)],
              s=60,edgecolors='k', linewidths=0.4,marker='o',color='silver',label='WIYN')

ax[3].scatter(plotD[:,0][np.where(plotD[:,0]>54.23)],plotD[:,1][np.where(plotD[:,0]>54.23)],
              s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue',label='GN')


ax[3].set_xlim([plotD[0,0]-0.01,plotD[0,0]-0.01+plotC[-1,0]-plotC[0,0]])

#October 29
ax[4].scatter(plotE[:,0],plotE[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax[4].set_xlim([plotE[0,0]-0.1,plotE[0,0]-0.1+plotC[-1,0]-plotC[0,0]])


#October 30
ax[5].scatter(plotF[:,0][np.where(plotF[:,0]<55.9)],plotF[:,1][np.where(plotF[:,0]<55.9)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='green',label='WHT')
ax[5].scatter(plotF[:,0][np.where(plotF[:,0]>56.1)],plotF[:,1][np.where(plotF[:,0]>56.1)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='pink',label='DCT')


ax[5].scatter(plotF[:,0][np.where((plotF[:,0]<56.1)&(plotF[:,0]>55.9))],
              plotF[:,1][np.where((plotF[:,0]<56.1)&(plotF[:,0]>55.9))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='purple',label='NOT')


ax[5].set_xlim([plotF[0,0]-0.01,plotF[0,0]-0.01+plotC[-1,0]-plotC[0,0]])


ax[0].set_title('Oct 25',fontsize=15)
ax[1].set_title('Oct 26',fontsize=15)
ax[2].set_title('Oct 27',fontsize=15)
ax[3].set_title('Oct 28',fontsize=15)
ax[4].set_title('Oct 29',fontsize=15)

ax[5].set_title('Oct 30',fontsize=15)
ax[10].axis('off')
ax[11].axis('off')
ax[9].axis('off')

ax[6].scatter(plotG[:,0],plotG[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='violet',label='HST')
ax[6].set_xlim([plotG[0,0]-0.1,plotG[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

ax[7].scatter(plotH[:,0],plotH[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='violet',label='HST')
ax[7].set_xlim([plotH[0,0]-0.1,plotH[0,0]-0.1+plotC[-1,0]-plotC[0,0]])

ax[8].scatter(plotI[:,0],plotI[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='yellow',label='CFH')
ax[8].set_xlim([plotI[0,0]-0.1,plotI[0,0]-0.1+plotC[-1,0]-plotC[0,0]])
#ax7.plot(plotG[:,0],plotG[:,1],'ko')
#ax8.plot(plotH[:,0],plotH[:,1],'ko')
#ax9.plot(plotI[:,0],plotI[:,1],'ko')

ax[6].set_title('Nov 21',fontsize=15)
ax[7].set_title('Nov 22',fontsize=15)
ax[8].set_title('Nov 23',fontsize=15)
ax[8].scatter(plotH[:,0],plotH[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='violet',label='HST')
ax[8].scatter(plotB[:,0][np.where(plotB[:,0]>52.11)],plotB[:,1][np.where(plotB[:,0]>52.11)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='orange',label='VLT')


ax[8].scatter(plotB[:,0][np.where(plotB[:,0]<52.05)],plotB[:,1][np.where(plotB[:,0]<52.05)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='purple',label='NOT')

ax[8].scatter(plotB[:,0][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))],plotB[:,1][np.where((plotB[:,0]>52.05) & (plotB[:,0]<52.11))]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='red',label='GS')
ax[8].scatter(plotC[:,0][np.where(plotC[:,0]>53.4)],plotC[:,1][np.where(plotC[:,0]>53.4)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue',label='GN')

ax[8].scatter(plotD[:,0][np.where(plotD[:,0]<54.23)],plotD[:,1][np.where(plotD[:,0]<54.23)],
              s=60,edgecolors='k', linewidths=0.4,marker='o',color='silver',label='WIYN')
ax[8].scatter(plotF[:,0][np.where(plotF[:,0]<55.9)],plotF[:,1][np.where(plotF[:,0]<55.9)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='green',label='WHT')
ax[8].scatter(plotF[:,0][np.where(plotF[:,0]>56.1)],plotF[:,1][np.where(plotF[:,0]>56.1)]
              ,s=60,edgecolors='k', linewidths=0.4,marker='o',color='pink',label='DCT')

lgnd=ax[8].legend(fancybox=True, framealpha=1, shadow=False, borderpad=1,bbox_to_anchor=(4.2,.2),
            frameon=True, loc='lower right', ncol=3,prop={'size': 25},facecolor='none')

for handle in lgnd.legendHandles:
    handle.set_sizes([500.0])

#ax6.grid(True,alpha=.6)
#ax7.grid(True,alpha=.6)
#ax8.grid(True,alpha=.6)
#ax9.grid(True,alpha=.6)

plt.savefig('/Users/darrylseligman/Dave/ARAA/Figures/LightCurve_Oumuamua/Oumuamua_LightCurve_ARAA_v2.pdf',
            rasterize=True, bbox_inches='tight', dpi=300)

# %%
#fig, axs = plt.subplots(2, 6, tight_layout=True,figsize=(12,4))

fig = plt.figure(constrained_layout=True,figsize=(14,6))

gs = GridSpec(2, 7, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2:4])
ax4 = fig.add_subplot(gs[0, 4])
ax5 = fig.add_subplot(gs[0, 5])
ax6 = fig.add_subplot(gs[0, 6])


ax1.set_ylim([25.9,21.])
ax2.set_ylim([25.9,21.])
ax2.set_yticks([])
ax3.set_ylim([25.9,21.])
ax3.set_yticks([])
ax4.set_ylim([25.9,21.])
ax4.set_yticks([])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0, 0), colspan=3))
#ax2 = fig.add_subplot(gs[1, :-1])
#ax3 = fig.add_subplot(gs[1:, -1])
#ax4 = fig.add_subplot(gs[-1, 0])
#ax5 = fig.add_subplot(gs[-1, -2])

ax1.set_xlabel('Oct 25',fontsize=15)
ax2.set_xlabel('Oct 26',fontsize=15)
ax3.set_xlabel('Oct 27',fontsize=15)
ax4.set_xlabel('Oct 28',fontsize=15)
ax5.set_xlabel('Oct 29',fontsize=15)

ax6.set_xlabel('Oct 30',fontsize=15)

ax1.scatter(plotA[:,0],plotA[:,1],s=60,edgecolors='k', linewidths=0.4,marker='o',color='deepskyblue')
ax2.plot(plotB[:,0],plotB[:,1],'ko')
ax3.plot(plotC[:,0],plotC[:,1],'ko')
ax4.plot(plotD[:,0],plotD[:,1],'ko')

# %%
#from matplotlib.pyplot import *
fig =plt.figure(figsize=(15,8))#plt.subplots()
ax1 = fig.add_axes([0.08, 0.6, 0.1, 0.35])#,sharex=ax)
ax1.set_ylim([25.9,21.])
ax2 = fig.add_axes([0.22, 0.6, 0.15, 0.35])#,sharex=ax)
ax2.set_ylim([25.9,21.])
ax3 = fig.add_axes([0.4, 0.6, 0.25, 0.35])#,sharex=ax)
ax3.set_ylim([25.9,21.])

ax4 = fig.add_axes([0.7, 0.6, 0.25, 0.35])#,sharex=ax)
ax4.set_ylim([25.9,21.])


#ax3 = fig.add_axes([0.7, 0.515, 0.25, 0.4])
ax5 = fig.add_axes([0.05, 0.1, 0.08, 0.35])
ax5.set_ylim([25.9,21.])

ax6 = fig.add_axes([0.155, 0.1, 0.25, 0.35])
ax6.set_ylim([25.9,21.])

ax7 = fig.add_axes([0.425, 0.1, 0.15, 0.35])
ax7.set_ylim([25.9,21.])

ax8 = fig.add_axes([0.6, 0.1, 0.225, 0.35])
ax8.set_ylim([25.9,21.])

ax9 = fig.add_axes([0.855, 0.1, 0.125, 0.35])
ax9.set_ylim([25.9,21.])

ax1.set_xlabel('Oct 25',fontsize=15)
ax2.set_xlabel('Oct 26',fontsize=15)
ax3.set_xlabel('Oct 27',fontsize=15)
ax4.set_xlabel('Oct 28',fontsize=15)
ax5.set_xlabel('Oct 29',fontsize=15)

ax6.set_xlabel('Oct 30',fontsize=15)

ax7.set_xlabel('Nov 21',fontsize=15)
ax8.set_xlabel('Nov 22',fontsize=15)
ax9.set_xlabel('Nov 23',fontsize=15)





ax1.set_ylabel('g Mag',fontsize=15)
ax5.set_ylabel('g Mag',fontsize=15)



#ax = fig.add_axes([0.035, 0.1, 0.6, 0.4])
ax1.plot(plotA[:,0],plotA[:,1],'ko')
ax2.plot(plotB[:,0],plotB[:,1],'ko')
ax3.plot(plotC[:,0],plotC[:,1],'ko')
ax4.plot(plotD[:,0],plotD[:,1],'ko')
ax5.plot(plotE[:,0],plotE[:,1],'ko')
ax6.plot(plotF[:,0],plotF[:,1],'ko')
ax7.plot(plotG[:,0],plotG[:,1],'ko')
ax8.plot(plotH[:,0],plotH[:,1],'ko')
ax9.plot(plotI[:,0],plotI[:,1],'ko')

ax1.grid(True,alpha=.6)
ax2.grid(True,alpha=.6)
ax3.grid(True,alpha=.6)
ax4.grid(True,alpha=.6)
ax5.grid(True,alpha=.6)
ax6.grid(True,alpha=.6)
ax7.grid(True,alpha=.6)
ax8.grid(True,alpha=.6)
ax9.grid(True,alpha=.6)

ax1.annotate('VLT', fontsize=14, xy=(51.05, 25.5),color='k',annotation_clip=False)
ax2.annotate('NOT', fontsize=14, xy=(52.0, 25.5),color='k',annotation_clip=False)

ax2.annotate('GS', fontsize=14, xy=(52.05, 25.5),color='k',annotation_clip=False)
ax2.annotate('VLT', fontsize=14, xy=(52.15, 25.5),color='k',annotation_clip=False)
ax3.annotate('GS', fontsize=14, xy=(53.15, 25.5),color='k',annotation_clip=False)

ax3.annotate('CFH', fontsize=14, xy=(53.285, 25.5),color='k',annotation_clip=False)
ax3.annotate('GN', fontsize=14, xy=(53.485, 25.5),color='k',annotation_clip=False)


ax4.annotate('WIYN', fontsize=14, xy=(54.15, 25.5),color='k',annotation_clip=False)
ax4.annotate('GN', fontsize=14, xy=(54.45, 25.5),color='k',annotation_clip=False)


ax5.annotate('GN', fontsize=14, xy=(55.25, 25.5),color='k',annotation_clip=False)

ax5.annotate('APO', fontsize=14, xy=(55.315, 25.5),color='k',annotation_clip=False)

ax6.annotate('WHT', fontsize=14, xy=(55.85, 25.5),color='k',annotation_clip=False)

ax6.annotate('NOT', fontsize=14, xy=(56.05, 25.5),color='k',annotation_clip=False)

ax6.annotate('DCT', fontsize=14, xy=(56.25, 25.5),color='k',annotation_clip=False)

ax7.annotate('Mag', fontsize=14, xy=(78.05, 25.5),color='k',annotation_clip=False)
ax7.annotate('HST', fontsize=14, xy=(78.2, 25.5),color='k',annotation_clip=False)
ax8.annotate('CFH', fontsize=14, xy=(79.25, 25.5),color='k',annotation_clip=False)

ax8.annotate('HST', fontsize=14, xy=(79.51, 25.5),color='k',annotation_clip=False)


ax9.annotate('CFH', fontsize=14, xy=(80.298, 25.5),color='k',annotation_clip=False)
# Out:
# Text(80.298,25.5,'CFH')
